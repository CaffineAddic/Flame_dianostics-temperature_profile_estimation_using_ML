# %%
import numpy as np
import matplotlib.pyplot as plt

import os

# %%
target = np.load('/home/saumya/Documents/Flame_dianostics-temperature_profile_estimation_using_ML/FINAL_VISUAL/Exp_test.npy')

# %%
source = np.load('/home/saumya/Documents/Flame_dianostics-temperature_profile_estimation_using_ML/Spectra_gen/final_deal.npy')

# %%
plt.plot(target)

# %%
plt.plot(source)

# %%
plt.plot(source-target)
plt.xlim(900,1100)
# Out:
# (900.0, 1100.0)
