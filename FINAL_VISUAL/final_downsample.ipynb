# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

# %%
df = pd.read_csv('/home/saumya/Documents/Spec_data/Exp_test_dta/non_un_spectrum_7444.csv')

# %%
df
# Out:
#       7444.02266791487  1.88662469329119e-05
# 0          7444.023187              0.000035
# 1          7444.023703              0.000036
# 2          7444.024216              0.000229
# 3          7444.024726              0.000597
# 4          7444.025233              0.000749
# ...                ...                   ...
# 6140       7444.924115              0.000655
# 6141       7444.924246              0.000624
# 6142       7444.924377              0.000340
# 6143       7444.924507              0.000220
# 6144       7444.924638              0.000339
#
# [6145 rows x 2 columns]

# %%
data = df.to_numpy()

# %%
data.shape
# Out:
# (6145, 2)

# %%
data
# Out:
# array([[7.44402319e+03, 3.54406789e-05],
#        [7.44402370e+03, 3.60397880e-05],
#        [7.44402422e+03, 2.28715207e-04],
#        ...,
#        [7.44492438e+03, 3.39664019e-04],
#        [7.44492451e+03, 2.20209006e-04],
#        [7.44492464e+03, 3.38858154e-04]])

# %%
plt.plot(data[:,1])

# %%
from scipy import signal
downsampled =  signal.resample(data[:,1], 3000)

# %%
plt.plot(downsampled)

# %%
np.save('Exp_test', downsampled)
