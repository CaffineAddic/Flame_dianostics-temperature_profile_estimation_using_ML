# %%
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

# %%
df = pd.read_csv('/home/saumya/Downloads/T_profile_fit.csv')

# %%
df
# Out:
#           0  398.995344402019
# 0      0.01        398.994814
# 1      0.02        398.994282
# 2      0.03        398.993749
# 3      0.04        398.993215
# 4      0.05        398.992680
# ...     ...               ...
# 5495  54.96         33.850372
# 5496  54.97         33.839100
# 5497  54.98         33.827850
# 5498  54.99         33.816623
# 5499  55.00         33.805419
#
# [5500 rows x 2 columns]

# %%
data = df.to_numpy()

# %%
data.shape
# Out:
# (5500, 2)

# %%
data
# Out:
# array([[1.00000000e-02, 3.98994814e+02],
#        [2.00000000e-02, 3.98994282e+02],
#        [3.00000000e-02, 3.98993749e+02],
#        ...,
#        [5.49800000e+01, 3.38278499e+01],
#        [5.49900000e+01, 3.38166229e+01],
#        [5.50000000e+01, 3.38054186e+01]])

# %%
plt.plot(data[:,1])

# %%
from scipy import signal
# downsampled =  signal.resample(data[:,1], 5000)


downsampled = data[:,1]

# %%
plt.plot(downsampled)

# %%
np.save('DOWN_temp', downsampled)

# %%
max(downsampled)
# Out:
# 398.994813701679

# %%
max(data[:,1])
# Out:
# 398.994813701679
